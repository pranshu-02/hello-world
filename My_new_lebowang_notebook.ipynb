# %% [markdown]
# <a href="https://colab.research.google.com/github/pranshu-02/hello-world/blob/master/My_new_lebowang_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Convolution Network for fMRI Analysis Based on Connectivity Neighborhood

# %% [markdown]
# # 1. Configuration

# %%
# !pip install PyDrive
# !pip install keras==2.1.5
# !pip install tensorflow==1.13.1
# !pip install h5py==2.8.0
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.7/dist-packages (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (1.12.8)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.26.3)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.17.4)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.15.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.0.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (57.4.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2018.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.2->PyDrive) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.2->PyDrive) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client>=1.2->PyDrive) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client>=1.2->PyDrive) (3.0.4)
# Collecting keras==2.1.5
#   Downloading Keras-2.1.5-py2.py3-none-any.whl (334 kB)
#      |████████████████████████████████| 334 kB 8.5 MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.5) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.1.5) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.5) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.1.5) (1.19.5)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.7.0
#     Uninstalling keras-2.7.0:
#       Successfully uninstalled keras-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.7.0 requires keras<2.8,>=2.7.0rc0, but you have keras 2.1.5 which is incompatible.
# Successfully installed keras-2.1.5
# Collecting tensorflow==1.13.1
#   Downloading tensorflow-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (92.6 MB)
#      |████████████████████████████████| 92.6 MB 1.2 MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.8.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (3.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.15.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.4.0)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 56.7 MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.19.5)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
#      |████████████████████████████████| 367 kB 41.8 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (0.37.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.42.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.1) (1.1.2)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.9 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.1) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.3.6)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1) (3.10.0.2)
# Collecting mock>=2.0.0
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.13.1) (1.5.2)
# Installing collected packages: mock, tensorflow-estimator, tensorboard, keras-applications, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.6 requires tensorflow>=2.0.0, but you have tensorflow 1.13.1 which is incompatible.
# Successfully installed keras-applications-1.0.8 mock-4.0.3 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0
# Collecting h5py==2.8.0
#   Downloading h5py-2.8.0-cp37-cp37m-manylinux1_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 10.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.8.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.8.0) (1.19.5)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.8.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import keras
import h5py
import tensorflow as tf

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id':"1pBNGcBAQt0jdD1AIZQ_EYW9aMf8g-BEu"})
downloaded.GetContentFile('model.py')

# or download from https://drive.google.com/file/d/1pBNGcBAQt0jdD1AIZQ_EYW9aMf8g-BEu/view?usp=sharing
from model import *

# %% [markdown]
# # Play with cGCN layer

# %% [markdown]
# ## Generate a random FC matrix

# %%
ROI_N = 236
random_FC = np.random.rand(ROI_N, ROI_N)
random_FC[np.diag_indices(ROI_N)] = 1
np.save('FC_random', random_FC)
plt.imshow(random_FC)
plt.show()

# %% [markdown]
# ## Obtain a k-NN graph

# %%
k = 5
kNN = random_FC.argsort(axis=1)[:, ::-1][:, 1:k+1] # copied from "get_model" function of "model.py" file
kNN_vis = np.zeros_like(random_FC)
for i in range(kNN.shape[0]):
    for j in range(kNN.shape[1]):
        kNN_vis[i, kNN[i, j]] = 1
plt.imshow(kNN_vis, cmap='binary')
plt.show()

# %% [markdown]
# ## Test function of "T_get_edge_feature" and "T_conv_bn_max"

# %%
frames = 100
ROI_N = 236
input_channel = 1
k = 5

print("B: Batch")
print("T: Time frames of fMRI clips")
print("N: No. of ROIs")
print("K: Directly connected neighbors, defined by the k value of the k-NN graph")
print("C: Channels")

print("                                   (B,   T,   N, K, C)")
input_tmp = tf.placeholder(tf.float32, shape=(None, frames, ROI_N, 1, input_channel))
print("Input shape:                      ", input_tmp.shape)
graph_tmp = tf.placeholder(tf.int32, shape=(None, ROI_N, k))
out_tmp = T_get_edge_feature(input_tmp, nn_idx=graph_tmp, k=k)

print("\nGetting the edge feature,")
print("intermediate output shape:        ", out_tmp.shape)

print("\nAfter Convolution (5 kernels) ")
out_tmp = T_conv_bn_max(out_tmp, 5)
print("and max aggregation, the output")
print("shape:                            ", out_tmp.shape)
# Out:
# B: Batch
# T: Time frames of fMRI clips
# N: No. of ROIs
# K: Directly connected neighbors, defined by the k value of the k-NN graph
# C: Channels
#                                    (B,   T,   N, K, C)
# Input shape:                       (?, 100, 236, 1, 1)
#
# Getting the edge feature,
# intermediate output shape:         (?, 100, 236, 5, 2)
#
# After Convolution (5 kernels)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/model.py:79: calling reduce_max_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# and max aggregation, the output
# shape:                             (?, 100, 236, 1, 5)

# %% [markdown]
# ## Test the function "T_edge_conv"

# %%
conv_kernels = [2, 4, 8, 16]

print("                                   (B,   T,   N, C)")
input_tmp0 = tf.placeholder(tf.float32, shape=(None, frames, ROI_N, input_channel))
print("Input shape:                      ", input_tmp0.shape)

input_tmp = tf.placeholder(tf.float32, shape=(None, frames, ROI_N, 1, input_channel))
print("\nWith the explicit dimension of")
print("directly connected neighbors:      (B,   T,   N, K, C)")
print("Input shape:                      ", input_tmp.shape)

for i, kernel in enumerate(conv_kernels, 1):
    out = input_tmp
    out = T_edge_conv(out, 
                      graph=tf.constant(kNN, dtype=tf.int32), 
                      kernel=kernel, k=k)
    print('\nAfter %d conv layer, output shape: '%i, out.shape)

out = tf.squeeze(out, -2)

print('\nW/o the redundant dimension,       (B,   T,   N, C)')
print('output shape:                     ', out.shape)
print('------------------------------------------------------')
print('\nLike common convolutions')
print('w/ conv kernels:', conv_kernels)
print('                                   (B,   T,   N, C)')
print('input data shape:                 ', input_tmp0.shape)
print('output data shape:                ', out.shape)
# Out:
#                                    (B,   T,   N, C)
# Input shape:                       (?, 100, 236, 1)
#
# With the explicit dimension of
# directly connected neighbors:      (B,   T,   N, K, C)
# Input shape:                       (?, 100, 236, 1, 1)
#
# After 1 conv layer, output shape:  (?, 100, 236, 1, 2)
#
# After 2 conv layer, output shape:  (?, 100, 236, 1, 4)
#
# After 3 conv layer, output shape:  (?, 100, 236, 1, 8)
#
# After 4 conv layer, output shape:  (?, 100, 236, 1, 16)
#
# W/o the redundant dimension,       (B,   T,   N, C)
# output shape:                      (?, 100, 236, 16)
# ------------------------------------------------------
#
# Like common convolutions
# w/ conv kernels: [2, 4, 8, 16]
#                                    (B,   T,   N, C)
# input data shape:                  (?, 100, 236, 1)
# output data shape:                 (?, 100, 236, 16)

# %% [markdown]
# # Overfit on small random datasets

# %% [markdown]
# ## Import data

# %%
N = 100
frames = 100
x_train_random = np.random.normal(0, 1, size=(N, frames, ROI_N, 1))
x_test_random = np.random.normal(0, 1, size=(N, frames, ROI_N, 1))
print('train data shape:', x_train_random.shape)
print('test data shape:', x_test_random.shape)

num_classes = 2
label_random = np.arange(num_classes).repeat(N // num_classes)
y_train_random_2 = y_test_random_2 = keras.utils.to_categorical(label_random, 2)
print('y_train_random_2 shape:', y_train_random_2.shape)
y_train_random_100 = y_test_random_100 = keras.utils.to_categorical(label_random, 100)
print('y_train_random_100_categories shape:', y_train_random_100.shape)
for label, count in enumerate(y_train_random_2.sum(0)):
    print('Label %d: %d/%d (%.1f%%)'%(label, count, y_train_random_2.shape[0], 100.0 * count / y_train_random_2.shape[0]))
# Out:
# train data shape: (100, 100, 236, 1)
# test data shape: (100, 100, 236, 1)
# y_train_random_2 shape: (100, 2)
# y_train_random_100_categories shape: (100, 100)
# Label 0: 50/100 (50.0%)
# Label 1: 50/100 (50.0%)

# %% [markdown]
# ## Get cGCN model

# %%
model = get_model(
    graph_path='FC_random.npy', 
    ROI_N=ROI_N,
    frames=frames, 
    kernels=[8,8,8,16,32,32], 
    k=3, 
    l2_reg=0, 
    dp=0,
    num_classes=num_classes, 
    weight_path=None, 
    skip=[0,0])
model.summary()

model.compile(loss=['categorical_crossentropy'], 
          optimizer=keras.optimizers.Adam(lr=0.001),
          metrics=['accuracy'])
# Out:
# load graph: FC_random.npy
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# points (InputLayer)             (None, 100, 236, 1)  0
# __________________________________________________________________________________________________
# graph (InputLayer)              (236, 3)             0
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 236, 3)       0           graph[0][0]
#                                                                  points[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 100, 236, 3,  0           points[0][0]
#                                                                  lambda_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 100, 236, 3,  24          lambda_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 100, 236, 3,  0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 100, 236, 1,  0           time_distributed_17[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 236, 3)       0           graph[0][0]
#                                                                  time_distributed_18[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 100, 236, 3,  0           time_distributed_18[0][0]
#                                                                  lambda_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 100, 236, 3,  136         lambda_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 100, 236, 3,  0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 100, 236, 1,  0           time_distributed_20[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 236, 3)       0           graph[0][0]
#                                                                  time_distributed_21[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 100, 236, 3,  0           time_distributed_21[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 100, 236, 3,  136         lambda_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 100, 236, 3,  0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 100, 236, 1,  0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 236, 3)       0           graph[0][0]
#                                                                  time_distributed_24[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 100, 236, 3,  0           time_distributed_24[0][0]
#                                                                  lambda_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 100, 236, 3,  272         lambda_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 100, 236, 3,  0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 100, 236, 1,  0           time_distributed_26[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 100, 236, 1,  0           time_distributed_18[0][0]
#                                                                  time_distributed_21[0][0]
#                                                                  time_distributed_24[0][0]
#                                                                  time_distributed_27[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 236, 3)       0           graph[0][0]
#                                                                  lambda_26[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 100, 236, 3,  0           lambda_26[0][0]
#                                                                  lambda_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 100, 236, 3,  2592        lambda_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 100, 236, 3,  0           time_distributed_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 100, 236, 1,  0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 100, 236, 1,  0           time_distributed_30[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)     (None, 100, 236, 1,  8320        time_distributed_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 100, 236, 1,  128         conv_lst_m2d_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 100, 236, 1,  0           time_distributed_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 100, 7552)    0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 100, 7552)    0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 100, 2)       15106       time_distributed_35[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 2)            0           time_distributed_36[0][0]
# ==================================================================================================
# Total params: 26,714
# Trainable params: 26,650
# Non-trainable params: 64
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
hist = model.fit(x_train_random, y_train_random_2,
        shuffle=True,
        batch_size=4,
        validation_data=(x_test_random, y_test_random_2),
        epochs=10)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 100 samples, validate on 100 samples
# Epoch 1/10
# 100/100 [==============================] - 65s 650ms/step - loss: 1.0099 - acc: 0.5600 - val_loss: 0.7494 - val_acc: 0.5000
# Epoch 2/10
# 100/100 [==============================] - 68s 675ms/step - loss: 0.7339 - acc: 0.5100 - val_loss: 0.7098 - val_acc: 0.5000
# Epoch 3/10
# 100/100 [==============================] - 64s 637ms/step - loss: 0.7057 - acc: 0.5100 - val_loss: 0.8563 - val_acc: 0.5000
# Epoch 4/10
# 100/100 [==============================] - 67s 667ms/step - loss: 0.5796 - acc: 0.6700 - val_loss: 0.7633 - val_acc: 0.5100
# Epoch 5/10
# 100/100 [==============================] - 60s 604ms/step - loss: 0.5719 - acc: 0.6900 - val_loss: 0.7204 - val_acc: 0.5100
# Epoch 6/10
# 100/100 [==============================] - 66s 657ms/step - loss: 0.5312 - acc: 0.7200 - val_loss: 0.8985 - val_acc: 0.4900
# Epoch 7/10
# 100/100 [==============================] - 62s 618ms/step - loss: 0.4796 - acc: 0.7800 - val_loss: 1.5553 - val_acc: 0.5000
# Epoch 8/10
# 100/100 [==============================] - 61s 615ms/step - loss: 0.3565 - acc: 0.9200 - val_loss: 1.5140 - val_acc: 0.5100
# Epoch 9/10
# 100/100 [==============================] - 61s 612ms/step - loss: 0.3291 - acc: 0.9400 - val_loss: 0.7993 - val_acc: 0.5400
# Epoch 10/10
# 100/100 [==============================] - 61s 612ms/step - loss: 0.2664 - acc: 0.9600 - val_loss: 1.2014 - val_acc: 0.5800

# %%
plt.plot(hist.history['acc'], label='Train acc')
plt.plot(hist.history['val_acc'], label='Test acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
print('Best train acc:', max(hist.history['acc']))
print('Best test acc:', max(hist.history['val_acc']))
# Best Train acc: ~100% (random: 50%).
# Best Test acc: ~50% (random: 50%).
# Out:
# Best train acc: 0.96
# Best test acc: 0.58

# %% [markdown]
# # Train and test on HCP dataset

# %% [markdown]
# ## Get HCP data

# %%
downloaded = drive.CreateFile({'id':"1l029ZuOIUY5gehBZCAyHaJqMNuxRHTFc"})
downloaded.GetContentFile('HCP.h5')
# Or download from https://drive.google.com/file/d/1l029ZuOIUY5gehBZCAyHaJqMNuxRHTFc/view?usp=sharing
with h5py.File('HCP.h5', 'r') as f:
    x_train, x_val, x_test = f['x_train'][()], f['x_val'][()], f['x_test'][()]
    y_train, y_val, y_test = f['y_train'][()], f['y_val'][()], f['y_test'][()]


x_train = np.expand_dims(x_train, -1) # (200, 100, 236, 1)
x_val = np.expand_dims(x_val, -1)
x_test = np.expand_dims(x_test, -1)
print ('x_train:', x_train.shape)
print ('x_val:', x_val.shape)
print ('x_test:', x_test.shape)

# Convert class vectors to binary class matrices.
num_classes = 100

y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print ('y_train:', y_train.shape)
print ('y_val:', y_val.shape)
print ('y_test:', y_test.shape)
# Out:
# x_train: (2400, 100, 236, 1)
# x_val: (1200, 100, 236, 1)
# x_test: (1200, 100, 236, 1)
# y_train: (2400, 100)
# y_val: (1200, 100)
# y_test: (1200, 100)

# %% [markdown]
# ## Get FC matrix

# %%
downloaded = drive.CreateFile({'id':"1WP4_9bps-NbX6GNBnhFu8itV3y1jriJL"})
downloaded.GetContentFile('FC.npy')
# Or download from https://drive.google.com/file/d/1WP4_9bps-NbX6GNBnhFu8itV3y1jriJL/view?usp=sharing
plt.imshow(np.load('FC.npy'))
plt.show()

# %% [markdown]
# ## Set parameter

# %%
num_classes = 100
k = 5 # (3, 5, 10, 20)
batch_size = 4
epochs = 10
l2_reg = 1e-4
dp = 0.5
lr = 1e-4

print('dp:', dp)
print('l2:', l2_reg)
print('batch_size:', batch_size)
print('epochs:', epochs)
print('lr:', lr)
# Out:
# dp: 0.5
# l2: 0.0001
# batch_size: 4
# epochs: 10
# lr: 0.0001

# %% [markdown]
# ## Train model

# %%
model = get_model(
    graph_path='FC.npy', 
    ROI_N=ROI_N,
    frames=frames,
    kernels=[8,8,8,16,32,32], 
    k=k, 
    l2_reg=l2_reg, 
    dp=dp,
    num_classes=num_classes, 
    weight_path=None, 
    skip=[0,0])
model.summary()

model.compile(loss=['categorical_crossentropy'], 
              optimizer=keras.optimizers.Adam(lr=lr),
              metrics=['accuracy'])

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_acc', factor=0.5,
                                              patience=10, min_lr=1e-6)
lr_hist = []
class Lr_record(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs={}):
        tmp = K.eval(model.optimizer.lr)
        lr_hist.append(tmp)
        print('Ir:', tmp)
lr_record = Lr_record()
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

checkpointer = keras.callbacks.ModelCheckpoint(monitor='val_acc', filepath='tmp.hdf5', 
                                                verbose=1, save_best_only=True)
# Out:
# load graph: FC.npy
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3138: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# points (InputLayer)             (None, 100, 236, 1)  0
# __________________________________________________________________________________________________
# graph (InputLayer)              (236, 5)             0
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 236, 5)       0           graph[0][0]
#                                                                  points[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 100, 236, 5,  0           points[0][0]
#                                                                  lambda_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 100, 236, 5,  24          lambda_32[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 100, 236, 5,  0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 100, 236, 1,  0           time_distributed_38[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 236, 5)       0           graph[0][0]
#                                                                  time_distributed_39[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 100, 236, 5,  0           time_distributed_39[0][0]
#                                                                  lambda_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 100, 236, 5,  136         lambda_35[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 100, 236, 5,  0           time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 100, 236, 1,  0           time_distributed_41[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 236, 5)       0           graph[0][0]
#                                                                  time_distributed_42[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 100, 236, 5,  0           time_distributed_42[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 100, 236, 5,  136         lambda_38[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 100, 236, 5,  0           time_distributed_43[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 100, 236, 1,  0           time_distributed_44[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 236, 5)       0           graph[0][0]
#                                                                  time_distributed_45[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 100, 236, 5,  0           time_distributed_45[0][0]
#                                                                  lambda_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 100, 236, 5,  272         lambda_41[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 100, 236, 5,  0           time_distributed_46[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 100, 236, 1,  0           time_distributed_47[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 100, 236, 1,  0           time_distributed_39[0][0]
#                                                                  time_distributed_42[0][0]
#                                                                  time_distributed_45[0][0]
#                                                                  time_distributed_48[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 236, 5)       0           graph[0][0]
#                                                                  lambda_43[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 100, 236, 5,  0           lambda_43[0][0]
#                                                                  lambda_44[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 100, 236, 5,  2592        lambda_45[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 100, 236, 5,  0           time_distributed_49[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 100, 236, 1,  0           time_distributed_50[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 100, 236, 1,  0           time_distributed_51[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)     (None, 100, 236, 1,  8320        time_distributed_52[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 100, 236, 1,  128         conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 100, 236, 1,  0           time_distributed_53[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 100, 7552)    0           time_distributed_54[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 100, 7552)    0           time_distributed_55[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 100, 100)     755300      time_distributed_56[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 100)          0           time_distributed_57[0][0]
# ==================================================================================================
# Total params: 766,908
# Trainable params: 766,844
# Non-trainable params: 64
# __________________________________________________________________________________________________

# %%
model_history = model.fit(x_train, y_train,
                            shuffle=True,
                            batch_size=batch_size,
                            epochs=epochs,
                            validation_data=(x_val, y_val),
                            callbacks=[checkpointer, lr_record, reduce_lr, earlystop])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 2400 samples, validate on 1200 samples
# Epoch 1/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1856s 773ms/step - loss: 4.9449 - acc: 0.0133 - val_loss: 4.6471 - val_acc: 0.0158
#
# Epoch 00001: val_acc improved from -inf to 0.01583, saving model to tmp.hdf5
# Epoch 2/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1854s 773ms/step - loss: 4.4354 - acc: 0.0462 - val_loss: 4.0886 - val_acc: 0.0717
#
# Epoch 00002: val_acc improved from 0.01583 to 0.07167, saving model to tmp.hdf5
# Epoch 3/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1834s 764ms/step - loss: 2.8609 - acc: 0.4071 - val_loss: 2.5525 - val_acc: 0.4142
#
# Epoch 00003: val_acc improved from 0.07167 to 0.41417, saving model to tmp.hdf5
# Epoch 4/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1808s 753ms/step - loss: 1.0649 - acc: 0.9250 - val_loss: 1.6686 - val_acc: 0.6292
#
# Epoch 00004: val_acc improved from 0.41417 to 0.62917, saving model to tmp.hdf5
# Epoch 5/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1819s 758ms/step - loss: 0.5060 - acc: 0.9971 - val_loss: 1.2851 - val_acc: 0.7375
#
# Epoch 00005: val_acc improved from 0.62917 to 0.73750, saving model to tmp.hdf5
# Epoch 6/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1821s 759ms/step - loss: 0.3409 - acc: 0.9992 - val_loss: 1.1100 - val_acc: 0.7642
#
# Epoch 00006: val_acc improved from 0.73750 to 0.76417, saving model to tmp.hdf5
# Epoch 7/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1820s 758ms/step - loss: 0.2606 - acc: 1.0000 - val_loss: 0.9793 - val_acc: 0.8075
#
# Epoch 00007: val_acc improved from 0.76417 to 0.80750, saving model to tmp.hdf5
# Epoch 8/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1822s 759ms/step - loss: 0.2134 - acc: 0.9996 - val_loss: 0.8920 - val_acc: 0.8167
#
# Epoch 00008: val_acc improved from 0.80750 to 0.81667, saving model to tmp.hdf5
# Epoch 9/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1821s 759ms/step - loss: 0.1774 - acc: 1.0000 - val_loss: 0.8789 - val_acc: 0.8275
#
# Epoch 00009: val_acc improved from 0.81667 to 0.82750, saving model to tmp.hdf5
# Epoch 10/10
# Ir: 1e-04
# 2400/2400 [==============================] - 1812s 755ms/step - loss: 0.1554 - acc: 1.0000 - val_loss: 0.8087 - val_acc: 0.8358
#
# Epoch 00010: val_acc improved from 0.82750 to 0.83583, saving model to tmp.hdf5

# %% [markdown]
# ## Test on a pre-trained model

# %%
downloaded = drive.CreateFile({'id':"1KePCfQOt1hk6TfL98Y4qnsFvdTSYPijh"})
downloaded.GetContentFile('model_k_5.hdf5')
# Or download from https://drive.google.com/file/d/1KePCfQOt1hk6TfL98Y4qnsFvdTSYPijh/view?usp=sharing

# %% [markdown]
# ### On random data

# %%
k = 5
model_val = get_model(
    graph_path='FC.npy', 
    ROI_N=ROI_N,
    frames=frames,
    kernels=[8,8,8,16,32,32], 
    k=k, 
    l2_reg=0, 
    dp=0,
    num_classes=100, 
    weight_path='model_k_5.hdf5', 
    skip=[0,0])

model_val.compile(loss=['categorical_crossentropy'], 
              optimizer=keras.optimizers.Adam(lr=0),
              metrics=['accuracy'])

test_tmp1 = model_val.evaluate(x=x_test_random, y=y_train_random_100, batch_size=4,verbose=1)
print('Test acc:', test_tmp1[1])
# Test acc close to the random chance (1%, 100 categories)
# Out:
# load graph: FC.npy
# Load weight: model_k_5.hdf5
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 100/100 [==============================] - 45s 452ms/step
# Test acc: 0.0

# %% [markdown]
# ### With random FC graph

# %%
k = 5
model_random = get_model(
    graph_path='FC_random.npy', 
    ROI_N=ROI_N,
    frames=frames,
    kernels=[8,8,8,16,32,32], 
    k=k, 
    l2_reg=0, 
    dp=0,
    num_classes=num_classes, 
    weight_path='model_k_5.hdf5', 
    skip=[0,0])

model_random.compile(loss=['categorical_crossentropy'], 
              optimizer=keras.optimizers.Adam(lr=0),
              metrics=['accuracy'])

test_tmp0 = model_random.evaluate(x=x_test, y=y_test, batch_size=4,verbose=1)
print('Test acc:', test_tmp0[1])
# Test acc is around 5% (random: 1%).
# Out:
# load graph: FC_random.npy
# Load weight: model_k_5.hdf5
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1200/1200 [==============================] - 538s 448ms/step
# Test acc: 0.045

# %% [markdown]
# ### With group FC graph

# %%
k = 5
model_val = get_model(
    graph_path='FC.npy', 
    ROI_N=ROI_N,
    frames=frames,
    kernels=[8,8,8,16,32,32], 
    k=k, 
    l2_reg=0, 
    dp=0,
    num_classes=num_classes, 
    weight_path='model_k_5.hdf5', 
    skip=[0,0])

model_val.compile(loss=['categorical_crossentropy'], 
              optimizer=keras.optimizers.Adam(lr=0),
              metrics=['accuracy'])

test_tmp1 = model_val.evaluate(x=x_test, y=y_test, batch_size=4,verbose=1)
print('Test acc:', test_tmp1[1])
# Test acc is 98.3% (random: 1%).
# Out:
# load graph: FC.npy
# Load weight: model_k_5.hdf5
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:96: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1200/1200 [==============================] - 539s 449ms/step
# Test acc: 0.9833333333333333
